# %%
 # %matplotlib notebook
import pandas as pd
 import matplotlib.pyplot as plt
import numpy as np

# %%
output_data = pd.read_csv('Output Data Clean.csv')
output_data.head()
# Out:
#          County   County Type  Violent Crime  \
# 0       Alameda  Metropolitan          10308
# 1         Butte  Metropolitan            751
# 2  Contra Costa  Metropolitan           4257
# 3     El Dorado  Metropolitan            485
# 4        Fresno  Metropolitan           4904
#
#    Murder and Nonnegligent Manslaughter  Forcible Rape  Robbery  \
# 0                                   132            519     4767
# 1                                     7             89      153
# 2                                    65            187     1525
# 3                                     3             34       66
# 4                                    63            181     1358
#
#    Aggravated Assault  Property Crime  Burglary  Larceny - Theft  \
# 0                4890           47547     11708            26822
# 1                 502            5464      1826             3265
# 2                2480           28491      7546            15494
# ...

# %%
# Filter the DataFrame down only to those columns to chart
population = output_data[["County","Population"]]

# Set the index to be "State" so they will be used as labels
population = population.set_index("County")

population.head()
# Out:
#               Population
# County
# Alameda          1510271
# Butte             220000
# Contra Costa     1049025
# El Dorado         181058
# Fresno            930450

# %%
population.plot(kind="bar", figsize=(40,6))

# Set a title for the chart
plt.title("Population by California County")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="4000">
